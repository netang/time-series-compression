# %%
ts = []
i = 1
for line in open('generated_datasets/gaussian_ts.txt','r'):
    if i == 1:
        i = i + 1
        continue
    splited=line.rstrip().split(";")
    ts.append(float(splited[2]))

# %%
len(ts)
# Out:
# 105264

# %%
import matplotlib.pyplot as plt
plt.plot(ts[:100])
