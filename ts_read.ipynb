# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ts_all = []
for file_idx in range(1,101):
    ts = []
    i = 1
    for line in open('generated_datasets/generated_ts_{0}.txt'.format(file_idx),'r'):
        if i == 1:
            i = i + 1
            continue
        splited=line.rstrip().split(";")
        ts.append(float(splited[2]))
    ts = ts[:262144]
    ts_all = ts_all + ts

# %%
len(ts_all)
# Out:
# 26214400

# %%
ts = []
i = 1
for line in open('generated_datasets/generated_ts_zstd_test_noise_plus_gaussian.txt','r'):
    if i == 1:
        i = i + 1
        continue
    splited=line.rstrip().split(";")
    ts.append(float(splited[2]))

# %%
ts = []
i = 1
for line in open('generated_datasets/generated_ts_zstd_test_without_noise_and_gaussian.txt','r'):
    if i == 1:
        i = i + 1
        continue
    splited=line.rstrip().split(";")
    ts.append(float(splited[2]))

# %%
len(ts)
# Out:
# 876672

# %%
ts = ts[:876544]

# %%
# ts = ts[:262144]
# len(ts)
# Out:
# 262144

# %%
plt.plot(ts[:1024])

# %%
reshaped_ts = np.reshape(ts, (856, 1024), order='C')

print(reshaped_ts.shape)
# Out:
# (856, 1024)

# %% [markdown]
# # Without noise

# %%
plt.plot(reshaped_ts[0][:1024])

# %%
reshaped_ts = np.reshape(ts_all, (25600, 1024), order='C')

print(reshaped_ts.shape)
# Out:
# (25600, 1024)

# %%
reshaped_ts = reshaped_ts / np.amax(reshaped_ts)
print('Min: {0}'.format(np.min(reshaped_ts)))
print('Max: {0}'.format(np.max(reshaped_ts)))
# Out:
# Min: 0.038132312886462176
# Max: 1.0

# %%
plt.plot(reshaped_ts[0][:1024])

# %%
reshaped_ts.shape
# Out:
# (856, 1024)

# %%
std_list = np.std(reshaped_ts, axis=1)

# %%
std_list.shape
# Out:
# (856,)

# %%
np.mean(std_list)
# Out:
# 50155309.71726496

# %%
reshaped_ts = np.reshape(ts_all, (25600, 1024), order='C')

print(reshaped_ts.shape)
# Out:
# (25600, 1024)

# %%
len(reshaped_ts)
# Out:
# 856

# %%
np.save('generated_datasets/generated_ts_zstd_test', reshaped_ts)

# %%
np.save('generated_datasets/tsimulus_cli_generated_ts_L1024', reshaped_ts)
